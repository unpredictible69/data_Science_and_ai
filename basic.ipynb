# %%
_A="Aayam"
_P="Pokhrel"
print(_A+" "+_P)
print("wow so genius")
# Out:
# Aayam Pokhrel
# wow so genius

# %%
#data types
STR="String"
integer=10
floating=10.5
complex_data=2j
listed=["Aayam","Pokhrel"]
tuples=("Aayam","Pokhrel")
range_value=range(7)
dictionary={"name":"Aayam","surname":"Pokhrel"}
set_data={"Aayam","pokhrel"}
frozen_set=frozenset({"Aayam","Pokhrel"})
is_it=True
or_is_it=False
bytes_data=b"Aayam?"
byte_array=bytearray(5)
memory_view=memoryview(bytes(5))
none_type=None
print("STR: ",STR)
print("integer: ",integer)
print("floating: ",floating)
print("complex_data: ",complex_data)
print("listed: ",listed)
print("tuples: ",tuples)
print("range_value: ",range_value)
print("dictionary: ",dictionary)
print("set_data: ",set_data)
print("frozen_set: ",frozen_set)
print("is_it: ",is_it)
print("or_is_it: ",or_is_it)
print("bytes_data: ",bytes_data)
print("bytearray: ",byte_array)
print("memory_view: ",memory_view)
print("none_type: ",none_type)
print(list(bytes_data))
name = bytearray("Aayam", "utf-8")
print("This is output:",name)
print(list(name))
name = bytearray("Aayam", "utf-8")
# Out:
# STR:  String
# integer:  10
# floating:  10.5
# complex_data:  2j
# listed:  ['Aayam', 'Pokhrel']
# tuples:  ('Aayam', 'Pokhrel')
# range_value:  range(0, 7)
# dictionary:  {'name': 'Aayam', 'surname': 'Pokhrel'}
# set_data:  {'pokhrel', 'Aayam'}
# frozen_set:  frozenset({'Pokhrel', 'Aayam'})
# is_it:  True
# or_is_it:  False
# bytes_data:  b'Aayam?'
# bytearray:  bytearray(b'\x00\x00\x00\x00\x00')
# memory_view:  <memory at 0x7f2516008700>
# none_type:  None
# [65, 97, 121, 97, 109, 63]
# This is output: bytearray(b'Aayam')
# [65, 97, 121, 97, 109]
